# %%
import pandas as pd

# %%
df = pd.DataFrame( [[4, 7, 10], [5, 8, 11],[6, 9, 12]],index=[1, 2, 3], columns=['a', 'b', 'c'])

# %%
df
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df2 = pd.DataFrame({'name':['John','Joe','Sally'],'Address':['Toronto','Kingston','Oakville']})

# %%
df2
# Out:
#     name   Address
# 0   John   Toronto
# 1    Joe  Kingston
# 2  Sally  Oakville

# %%
dftest = pd.DataFrame({'name':['John','Joe','Sally'],'Address':['Toronto','Kingston','Oakville']},index=['a','b','c'])

# %%
dftest
# Out:
#     name   Address
# a   John   Toronto
# b    Joe  Kingston
# c  Sally  Oakville

# %%
#read csv file with pandas
data = pd.read_csv('cars.csv')

# %%
data
# Out:
#             make    model      color  year  doors
# 0         Toyota    prius  white2018     4    NaN
# 1            BMW       X5       blue  2016    4.0
# 2          Tesla  Model S      White  2017    4.0
# 3          Honda   Accord      Black  2019    4.0
# 4  Mercedes Benz       C3       Blue  2016    4.0

# %%
#read a file that is tab seperated
products = pd.read_csv('products-2.csv', sep='\t')

# %%
products
# Out:
#      ProductID                   Name ProductNumber  MakeFlag  \
# 0            1        Adjustable Race       AR-5381         0
# 1            2           Bearing Ball       BA-8327         0
# 2            3        BB Ball Bearing       BE-2349         1
# 3            4  Headset Ball Bearings       BE-2908         0
# 4          316                  Blade       BL-2036         1
# ..         ...                    ...           ...       ...
# 499        995      ML Bottom Bracket       BB-8107         1
# 500        996      HL Bottom Bracket       BB-9108         1
# 501        997      Road-750 Black 44    BK-R19B-44         1
# 502        998      Road-750 Black 48    BK-R19B-48         1
# 503        999      Road-750 Black 52    BK-R19B-52         1
#
#      FinishedGoodsFlag  Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0                    0    NaN              1000           750        0.0000
# ...

# %%
#how many rows and colums (.shape)
products.shape
# Out:
# (504, 25)

# %%
#inspect our data , Withouth printing
products.head () #gives us the first 5 rows
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381         0
# 1          2           Bearing Ball       BA-8327         0
# 2          3        BB Ball Bearing       BE-2349         1
# 3          4  Headset Ball Bearings       BE-2908         0
# 4        316                  Blade       BL-2036         1
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0                  0   NaN              1000           750           0.0
# 1                  0   NaN              1000           750           0.0
# 2                  0   NaN               800           600           0.0
# 3                  0   NaN               800           600           0.0
# 4                  0   NaN               800           600           0.0
#
#    ListPrice  ... ProductLine Class Style  ProductSubcategoryID  \
# 0        0.0  ...         NaN   NaN   NaN                   NaN
# ...

# %%
#last five rows
products.tail()
# Out:
#      ProductID               Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# 499        995  ML Bottom Bracket       BB-8107         1                  1
# 500        996  HL Bottom Bracket       BB-9108         1                  1
# 501        997  Road-750 Black 44    BK-R19B-44         1                  1
# 502        998  Road-750 Black 48    BK-R19B-48         1                  1
# 503        999  Road-750 Black 52    BK-R19B-52         1                  1
#
#      Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  ...  \
# 499    NaN               500           375       44.9506     101.24  ...
# 500    NaN               500           375       53.9416     121.49  ...
# 501  Black               100            75      343.6496     539.99  ...
# 502  Black               100            75      343.6496     539.99  ...
# 503  Black               100            75      343.6496     539.99  ...
#
# ...

# %%
#summary stats 
#basic stastical summary of all numbers values in the dataset
products.describe()
# Out:
#         ProductID    MakeFlag  FinishedGoodsFlag  SafetyStockLevel  \
# count  504.000000  504.000000         504.000000        504.000000
# mean   673.039683    0.474206           0.585317        535.150794
# std    229.373142    0.499830           0.493157        374.112954
# min      1.000000    0.000000           0.000000          4.000000
# 25%    447.750000    0.000000           0.000000        100.000000
# 50%    747.500000    0.000000           1.000000        500.000000
# 75%    873.250000    1.000000           1.000000       1000.000000
# max    999.000000    1.000000           1.000000       1000.000000
#
#        ReorderPoint  StandardCost    ListPrice       Weight  \
# count    504.000000    504.000000   504.000000   205.000000
# mean     401.363095    258.602961   438.666250    74.069220
# std      280.584715    461.632808   773.602843   182.166588
# min        3.000000      0.000000     0.000000     2.120000
# ...

# %%
#displaying subsets of our dataset
products['ListPrice'] #this returns a pandas series data
# Out:
# 0        0.00
# 1        0.00
# 2        0.00
# 3        0.00
# 4        0.00
#         ...
# 499    101.24
# 500    121.49
# 501    539.99
# 502    539.99
# 503    539.99
# Name: ListPrice, Length: 504, dtype: float64

# %%
products[['ProductID','ListPrice','Color','Weight']] #this is a data frame
# Out:
#      ProductID  ListPrice  Color  Weight
# 0            1       0.00    NaN     NaN
# 1            2       0.00    NaN     NaN
# 2            3       0.00    NaN     NaN
# 3            4       0.00    NaN     NaN
# 4          316       0.00    NaN     NaN
# ..         ...        ...    ...     ...
# 499        995     101.24    NaN  168.00
# 500        996     121.49    NaN  170.00
# 501        997     539.99  Black   19.77
# 502        998     539.99  Black   20.13
# 503        999     539.99  Black   20.42
#
# [504 rows x 4 columns]

# %%
#list the columns in the dataframe
products.columns
# Out:
# Index(['ProductID', 'Name', 'ProductNumber', 'MakeFlag', 'FinishedGoodsFlag',
#        'Color', 'SafetyStockLevel', 'ReorderPoint', 'StandardCost',
#        'ListPrice', 'Size', 'SizeUnitMeasureCode', 'WeightUnitMeasureCode',
#        'Weight', 'DaysToManufacture', 'ProductLine', 'Class', 'Style',
#        'ProductSubcategoryID', 'ProductModelID', 'SellStartDate',
#        'SellEndDate', 'DiscontinuedDate', 'rowguid', 'ModifiedDate'],
#       dtype='object')

# %%
#subsets of our data based on contains conditions
#show all the products that are black [productid,color,weight]
#products[products['Color'] == 'Black']
products[products['Color'] == 'Black'][['ProductID','Color','Weight']]
# Out:
#      ProductID  Color  Weight
# 5          317  Black     NaN
# 6          318  Black     NaN
# 7          319  Black     NaN
# 10         322  Black     NaN
# 209        680  Black    2.24
# ..         ...    ...     ...
# 496        992  Black   28.42
# 497        993  Black   28.68
# 501        997  Black   19.77
# 502        998  Black   20.13
# 503        999  Black   20.42
#
# [93 rows x 3 columns]

# %%
#list the productID, Name and ReorderPoint of the products with a listprice greater than 500
products[products['ListPrice'] >= 500] [['ProductID', 'Name','ReorderPoint']]
# Out:
#      ProductID                      Name  ReorderPoint
# 209        680  HL Road Frame - Black 58           375
# 210        706    HL Road Frame - Red 58           375
# 221        717    HL Road Frame - Red 62           375
# 222        718    HL Road Frame - Red 44           375
# 223        719    HL Road Frame - Red 48           375
# ..         ...                       ...           ...
# 496        992     Mountain-500 Black 48            75
# 497        993     Mountain-500 Black 52            75
# 501        997         Road-750 Black 44            75
# 502        998         Road-750 Black 48            75
# 503        999         Road-750 Black 52            75
#
# [136 rows x 3 columns]
